# %%
import matplotlib.pyplot as plt

a=[10,15,3,8,20,25,30,31,32,35,39,37,40,42,51,60,62,70,72,73,80,85,86,87,89]
plt.violinplot(a,showmedians=True,showextrema=True,)
plt.show()

# %%
import pandas as pd
data=pd.read_excel("dataSets/ESD.xlsx")
df=pd.DataFrame(data)
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
import pandas as pd
data=pd.read_excel("dataSets/ESD.xlsx")
df=pd.DataFrame(data)
plt.violinplot((df["Annual Salary"]),showmedians=True)

plt.show()

# %%
import pandas as pd
data=pd.read_excel("dataSets/ESD.xlsx")
df=pd.DataFrame(data)
plt.violinplot((df["Age"]),showmedians=True)
plt.show()

# %%
import pandas as pd
data=pd.read_excel("dataSets/ESD.xlsx")
df=pd.DataFrame(data)
plt.violinplot((df["Gender"]),showmedians=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       2 data=pd.read_excel("dataSets/ESD.xlsx")
#       3 df=pd.DataFrame(data)
# ----> 4 plt.violinplot((df["Gender"]),showmedians=True)
#       5 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:4263, in violinplot(dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method, side, data)
#    4244 @_copy_docstring_and_deprecators(Axes.violinplot)
#    4245 def violinplot(
#    4246     dataset: ArrayLike | Sequence[ArrayLike],
#    (...)
#    4261     data=None,
#    4262 ) -> dict[str, Collection]:
# -> 4263     return gca().violinplot(
#    4264         dataset,
#    4265         positions=positions,
#    4266         vert=vert,
#    4267         widths=widths,
#    4268         showmeans=showmeans,
# ...
